# %%
# libraries
import torch
from model import get_core_model_params, get_trained_linear, freeze
from dataset import split_user_train_dataset_to_remaining_forget, get_remaining_forget_loader
from utils import params_to_device
from loss import MSELossDiv2
import os

device = 'cpu:3' if torch.cuda.is_available() else 'cpu'

# %%
# load pretrained model
exp_path = 'checkpoint/05152024-011132-train-user-data-resnet18-cifar10-last1/'
core_model_state_dict = get_core_model_params(os.path.join(exp_path, '05152024_011132_train_user_data_resnet18_cifar10_last1_core_model.pth'), 'cpu')
feature_backbone, mixed_linear = get_trained_linear(os.path.join(exp_path, '05152024_011132_train_user_data_resnet18_cifar10_last1.pth'), 'resnet18', 'cifar10', 1)

feature_backbone = feature_backbone.to(device)
freeze(feature_backbone)

mixed_linear = mixed_linear.to(device)
freeze(mixed_linear)

core_model_state_dict = params_to_device(core_model_state_dict, device)

## split dataset into remaning and forget
remaining_dataset, forget_dataset = split_user_train_dataset_to_remaining_forget('cifar10', 'resnet18', 0.1)
remain_loader, forget_loader = get_remaining_forget_loader(remaining_dataset, forget_dataset, 256)
# Out:
# Files already downloaded and verified

# %%
# calculate the hessian on the last linear layer for both remaning and forget
def calculate_hessian(backbone, loader, exp_path, mode='forget'):
    print('{} hessian'.format(mode))
    hessian = None
    sample_count = 0
    with torch.no_grad():
        for iter, (data, _) in enumerate(loader):
            data = data.to(device)
            act = backbone(data).squeeze()
            act = act.unsqueeze(-1)
            batched_hessian = act @ act.permute(0, 2, 1)
            if hessian is None:
                hessian = torch.sum(batched_hessian, dim=0).clone().detach().to('cpu')
            else:
                hessian += torch.sum(batched_hessian, dim=0).clone().detach().to('cpu')
            sample_count += data.shape[0]
            if (iter + 1) % 50 == 0 or (iter + 1) == len(loader):
                print('iter: {}/{}'.format(iter + 1, len(loader))) 
    hessian = hessian / sample_count
    torch.save({'hessian': hessian}, os.path.join(exp_path, '05152024_011132_train_user_data_resnet18_cifar10_last1_{}_hessian.pth'.format(mode)))
    return hessian

forget_hessian = calculate_hessian(feature_backbone, forget_loader, exp_path, mode='forget')
remain_hessian = calculate_hessian(feature_backbone, remain_loader, exp_path, mode='remain')
# Out:
# forget hessian
# iter: 20/20
# remain hessian
# iter: 50/176
# iter: 100/176
# iter: 150/176
# iter: 176/176

# %%
# sample perturbed parameters
## perturb from gradient direction
## NOTE: we can analyze the effects of sampling different perturbations and its importance

trained_mixed_linear_weights = [key.clone().detach().to('cpu') for key in mixed_linear.tangents.values()]
num_of_perturbations = 500
scale_random = 0.01

# using default random perturbation
perturbations = []
perturbed_weights = []
for _ in range(num_of_perturbations):
    curr_perturb = [torch.randn(*weight.shape) * scale_random for weight in trained_mixed_linear_weights]
    curr_perturbed_weight = [weight + perturb for weight, perturb in zip(trained_mixed_linear_weights, curr_perturb)]
    perturbations.append(curr_perturb)
    perturbed_weights.append(curr_perturbed_weight)
torch.save({'perturbations': perturbations}, os.path.join(exp_path, '05152024_011132_train_user_data_resnet18_cifar10_last1_perturbations.pth'))
torch.save({'perturbed_weights': perturbed_weights}, os.path.join(exp_path, '05152024_011132_train_user_data_resnet18_cifar10_last1_perturbed_weights.pth'))

# %%
# find out loss differences (L_forget)
criterion = MSELossDiv2()
forget_loss_differences = torch.zeros(num_of_perturbations).to(device)
sample_count = 0
mixed_linear.eval()
with torch.no_grad():
    for iter, (data, label) in enumerate(forget_loader):
        data, label = data.to(device), label.to(device)
        label = label * 5
        preds = mixed_linear(feature_backbone, core_model_state_dict, data)
        actual_loss = criterion(preds, label)
        sample_count += data.shape[0]
        for perturb_idx, perturbed_weight in enumerate(perturbed_weights):
            mixed_linear.to('cpu')
            state_dict = mixed_linear.state_dict()
            for key, perturbed in zip(state_dict.keys(), perturbed_weight):
                state_dict[key] = perturbed
            mixed_linear.load_state_dict(state_dict)
            mixed_linear.to(device)
            perturbed_preds = mixed_linear(feature_backbone, core_model_state_dict, data)
            perturbed_loss = criterion(perturbed_preds, label)
            forget_loss_differences[perturb_idx] += (perturbed_loss - actual_loss) * 2 * data.shape[0]
            if (perturb_idx + 1) % 10 == 0 or (perturb_idx + 1) == len(forget_loader):
                print('iter: {}/{} perturb: {}/{}'.format(iter + 1, len(forget_loader), perturb_idx + 1, len(perturbed_weights)))
    forget_loss_differences = forget_loss_differences / sample_count
    forget_loss_differences = forget_loss_differences.to('cpu')
# Out:
# iter: 1/20 perturb: 10/500
# iter: 1/20 perturb: 20/500
# iter: 1/20 perturb: 30/500
# iter: 1/20 perturb: 40/500
# iter: 1/20 perturb: 50/500
# iter: 1/20 perturb: 60/500
# iter: 1/20 perturb: 70/500
# iter: 1/20 perturb: 80/500
# iter: 1/20 perturb: 90/500
# iter: 1/20 perturb: 100/500
# iter: 1/20 perturb: 110/500
# iter: 1/20 perturb: 120/500
# iter: 1/20 perturb: 130/500
# iter: 1/20 perturb: 140/500
# iter: 1/20 perturb: 150/500
# iter: 1/20 perturb: 160/500
# iter: 1/20 perturb: 170/500
# iter: 1/20 perturb: 180/500
# iter: 1/20 perturb: 190/500
# iter: 1/20 perturb: 200/500
# iter: 1/20 perturb: 210/500
# iter: 1/20 perturb: 220/500
# iter: 1/20 perturb: 230/500
# iter: 1/20 perturb: 240/500
# iter: 1/20 perturb: 250/500
# iter: 1/20 perturb: 260/500
# iter: 1/20 perturb: 270/500
# iter: 1/20 perturb: 280/500
# iter: 1/20 perturb: 290/500
# iter: 1/20 perturb: 300/500
# iter: 1/20 perturb: 310/500
# iter: 1/20 perturb: 320/500
# iter: 1/20 perturb: 330/500
# iter: 1/20 perturb: 340/500
# iter: 1/20 perturb: 350/500
# iter: 1/20 perturb: 360/500
# iter: 1/20 perturb: 370/500
# iter: 1/20 perturb: 380/500
# iter: 1/20 perturb: 390/500
# iter: 1/20 perturb: 400/500
# iter: 1/20 perturb: 410/500
# iter: 1/20 perturb: 420/500
# iter: 1/20 perturb: 430/500
# iter: 1/20 perturb: 440/500
# iter: 1/20 perturb: 450/500
# iter: 1/20 perturb: 460/500
# iter: 1/20 perturb: 470/500
# iter: 1/20 perturb: 480/500
# iter: 1/20 perturb: 490/500
# iter: 1/20 perturb: 500/500
# iter: 2/20 perturb: 10/500
# iter: 2/20 perturb: 20/500
# iter: 2/20 perturb: 30/500
# iter: 2/20 perturb: 40/500
# iter: 2/20 perturb: 50/500
# iter: 2/20 perturb: 60/500
# iter: 2/20 perturb: 70/500
# iter: 2/20 perturb: 80/500
# iter: 2/20 perturb: 90/500
# iter: 2/20 perturb: 100/500
# iter: 2/20 perturb: 110/500
# iter: 2/20 perturb: 120/500
# iter: 2/20 perturb: 130/500
# iter: 2/20 perturb: 140/500
# iter: 2/20 perturb: 150/500
# iter: 2/20 perturb: 160/500
# iter: 2/20 perturb: 170/500
# iter: 2/20 perturb: 180/500
# iter: 2/20 perturb: 190/500
# iter: 2/20 perturb: 200/500
# iter: 2/20 perturb: 210/500
# iter: 2/20 perturb: 220/500
# iter: 2/20 perturb: 230/500
# iter: 2/20 perturb: 240/500
# iter: 2/20 perturb: 250/500
# iter: 2/20 perturb: 260/500
# iter: 2/20 perturb: 270/500
# iter: 2/20 perturb: 280/500
# iter: 2/20 perturb: 290/500
# iter: 2/20 perturb: 300/500
# iter: 2/20 perturb: 310/500
# iter: 2/20 perturb: 320/500
# iter: 2/20 perturb: 330/500
# iter: 2/20 perturb: 340/500
# iter: 2/20 perturb: 350/500
# iter: 2/20 perturb: 360/500
# iter: 2/20 perturb: 370/500
# iter: 2/20 perturb: 380/500
# iter: 2/20 perturb: 390/500
# iter: 2/20 perturb: 400/500
# iter: 2/20 perturb: 410/500
# iter: 2/20 perturb: 420/500
# iter: 2/20 perturb: 430/500
# iter: 2/20 perturb: 440/500
# iter: 2/20 perturb: 450/500
# iter: 2/20 perturb: 460/500
# iter: 2/20 perturb: 470/500
# iter: 2/20 perturb: 480/500
# iter: 2/20 perturb: 490/500
# iter: 2/20 perturb: 500/500
# iter: 3/20 perturb: 10/500
# iter: 3/20 perturb: 20/500
# iter: 3/20 perturb: 30/500
# iter: 3/20 perturb: 40/500
# iter: 3/20 perturb: 50/500
# iter: 3/20 perturb: 60/500
# iter: 3/20 perturb: 70/500
# iter: 3/20 perturb: 80/500
# iter: 3/20 perturb: 90/500
# iter: 3/20 perturb: 100/500
# iter: 3/20 perturb: 110/500
# iter: 3/20 perturb: 120/500
# iter: 3/20 perturb: 130/500
# iter: 3/20 perturb: 140/500
# iter: 3/20 perturb: 150/500
# iter: 3/20 perturb: 160/500
# iter: 3/20 perturb: 170/500
# iter: 3/20 perturb: 180/500
# iter: 3/20 perturb: 190/500
# iter: 3/20 perturb: 200/500
# iter: 3/20 perturb: 210/500
# iter: 3/20 perturb: 220/500
# iter: 3/20 perturb: 230/500
# iter: 3/20 perturb: 240/500
# iter: 3/20 perturb: 250/500
# iter: 3/20 perturb: 260/500
# iter: 3/20 perturb: 270/500
# iter: 3/20 perturb: 280/500
# iter: 3/20 perturb: 290/500
# iter: 3/20 perturb: 300/500
# iter: 3/20 perturb: 310/500
# iter: 3/20 perturb: 320/500
# iter: 3/20 perturb: 330/500
# iter: 3/20 perturb: 340/500
# iter: 3/20 perturb: 350/500
# iter: 3/20 perturb: 360/500
# iter: 3/20 perturb: 370/500
# iter: 3/20 perturb: 380/500
# iter: 3/20 perturb: 390/500
# iter: 3/20 perturb: 400/500
# iter: 3/20 perturb: 410/500
# iter: 3/20 perturb: 420/500
# iter: 3/20 perturb: 430/500
# iter: 3/20 perturb: 440/500
# iter: 3/20 perturb: 450/500
# iter: 3/20 perturb: 460/500
# iter: 3/20 perturb: 470/500
# iter: 3/20 perturb: 480/500
# iter: 3/20 perturb: 490/500
# iter: 3/20 perturb: 500/500
# iter: 4/20 perturb: 10/500
# iter: 4/20 perturb: 20/500
# iter: 4/20 perturb: 30/500
# iter: 4/20 perturb: 40/500
# iter: 4/20 perturb: 50/500
# iter: 4/20 perturb: 60/500
# iter: 4/20 perturb: 70/500
# iter: 4/20 perturb: 80/500
# iter: 4/20 perturb: 90/500
# iter: 4/20 perturb: 100/500
# iter: 4/20 perturb: 110/500
# iter: 4/20 perturb: 120/500
# iter: 4/20 perturb: 130/500
# iter: 4/20 perturb: 140/500
# iter: 4/20 perturb: 150/500
# iter: 4/20 perturb: 160/500
# iter: 4/20 perturb: 170/500
# iter: 4/20 perturb: 180/500
# iter: 4/20 perturb: 190/500
# iter: 4/20 perturb: 200/500
# iter: 4/20 perturb: 210/500
# iter: 4/20 perturb: 220/500
# iter: 4/20 perturb: 230/500
# iter: 4/20 perturb: 240/500
# iter: 4/20 perturb: 250/500
# iter: 4/20 perturb: 260/500
# iter: 4/20 perturb: 270/500
# iter: 4/20 perturb: 280/500
# iter: 4/20 perturb: 290/500
# iter: 4/20 perturb: 300/500
# iter: 4/20 perturb: 310/500
# iter: 4/20 perturb: 320/500
# iter: 4/20 perturb: 330/500
# iter: 4/20 perturb: 340/500
# iter: 4/20 perturb: 350/500
# iter: 4/20 perturb: 360/500
# iter: 4/20 perturb: 370/500
# iter: 4/20 perturb: 380/500
# iter: 4/20 perturb: 390/500
# iter: 4/20 perturb: 400/500
# iter: 4/20 perturb: 410/500
# iter: 4/20 perturb: 420/500
# iter: 4/20 perturb: 430/500
# iter: 4/20 perturb: 440/500
# iter: 4/20 perturb: 450/500
# iter: 4/20 perturb: 460/500
# iter: 4/20 perturb: 470/500
# iter: 4/20 perturb: 480/500
# iter: 4/20 perturb: 490/500
# iter: 4/20 perturb: 500/500
# iter: 5/20 perturb: 10/500
# iter: 5/20 perturb: 20/500
# iter: 5/20 perturb: 30/500
# iter: 5/20 perturb: 40/500
# iter: 5/20 perturb: 50/500
# iter: 5/20 perturb: 60/500
# iter: 5/20 perturb: 70/500
# iter: 5/20 perturb: 80/500
# iter: 5/20 perturb: 90/500
# iter: 5/20 perturb: 100/500
# iter: 5/20 perturb: 110/500
# iter: 5/20 perturb: 120/500
# iter: 5/20 perturb: 130/500
# iter: 5/20 perturb: 140/500
# iter: 5/20 perturb: 150/500
# iter: 5/20 perturb: 160/500
# iter: 5/20 perturb: 170/500
# iter: 5/20 perturb: 180/500
# iter: 5/20 perturb: 190/500
# iter: 5/20 perturb: 200/500
# iter: 5/20 perturb: 210/500
# iter: 5/20 perturb: 220/500
# iter: 5/20 perturb: 230/500
# iter: 5/20 perturb: 240/500
# iter: 5/20 perturb: 250/500
# iter: 5/20 perturb: 260/500
# iter: 5/20 perturb: 270/500
# iter: 5/20 perturb: 280/500
# iter: 5/20 perturb: 290/500
# iter: 5/20 perturb: 300/500
# iter: 5/20 perturb: 310/500
# iter: 5/20 perturb: 320/500
# iter: 5/20 perturb: 330/500
# iter: 5/20 perturb: 340/500
# iter: 5/20 perturb: 350/500
# iter: 5/20 perturb: 360/500
# iter: 5/20 perturb: 370/500
# iter: 5/20 perturb: 380/500
# iter: 5/20 perturb: 390/500
# iter: 5/20 perturb: 400/500
# iter: 5/20 perturb: 410/500
# iter: 5/20 perturb: 420/500
# iter: 5/20 perturb: 430/500
# iter: 5/20 perturb: 440/500
# iter: 5/20 perturb: 450/500
# iter: 5/20 perturb: 460/500
# iter: 5/20 perturb: 470/500
# iter: 5/20 perturb: 480/500
# iter: 5/20 perturb: 490/500
# iter: 5/20 perturb: 500/500
# iter: 6/20 perturb: 10/500
# iter: 6/20 perturb: 20/500
# iter: 6/20 perturb: 30/500
# iter: 6/20 perturb: 40/500
# iter: 6/20 perturb: 50/500
# iter: 6/20 perturb: 60/500
# iter: 6/20 perturb: 70/500
# iter: 6/20 perturb: 80/500
# iter: 6/20 perturb: 90/500
# iter: 6/20 perturb: 100/500
# iter: 6/20 perturb: 110/500
# iter: 6/20 perturb: 120/500
# iter: 6/20 perturb: 130/500
# iter: 6/20 perturb: 140/500
# iter: 6/20 perturb: 150/500
# iter: 6/20 perturb: 160/500
# iter: 6/20 perturb: 170/500
# iter: 6/20 perturb: 180/500
# iter: 6/20 perturb: 190/500
# iter: 6/20 perturb: 200/500
# iter: 6/20 perturb: 210/500
# iter: 6/20 perturb: 220/500
# iter: 6/20 perturb: 230/500
# iter: 6/20 perturb: 240/500
# iter: 6/20 perturb: 250/500
# iter: 6/20 perturb: 260/500
# iter: 6/20 perturb: 270/500
# iter: 6/20 perturb: 280/500
# iter: 6/20 perturb: 290/500
# iter: 6/20 perturb: 300/500
# iter: 6/20 perturb: 310/500
# iter: 6/20 perturb: 320/500
# iter: 6/20 perturb: 330/500
# iter: 6/20 perturb: 340/500
# iter: 6/20 perturb: 350/500
# iter: 6/20 perturb: 360/500
# iter: 6/20 perturb: 370/500
# iter: 6/20 perturb: 380/500
# iter: 6/20 perturb: 390/500
# iter: 6/20 perturb: 400/500
# iter: 6/20 perturb: 410/500
# iter: 6/20 perturb: 420/500
# iter: 6/20 perturb: 430/500
# iter: 6/20 perturb: 440/500
# iter: 6/20 perturb: 450/500
# iter: 6/20 perturb: 460/500
# iter: 6/20 perturb: 470/500
# iter: 6/20 perturb: 480/500
# iter: 6/20 perturb: 490/500
# iter: 6/20 perturb: 500/500
# iter: 7/20 perturb: 10/500
# iter: 7/20 perturb: 20/500
# iter: 7/20 perturb: 30/500
# iter: 7/20 perturb: 40/500
# iter: 7/20 perturb: 50/500
# iter: 7/20 perturb: 60/500
# iter: 7/20 perturb: 70/500
# iter: 7/20 perturb: 80/500
# iter: 7/20 perturb: 90/500
# iter: 7/20 perturb: 100/500
# iter: 7/20 perturb: 110/500
# iter: 7/20 perturb: 120/500
# iter: 7/20 perturb: 130/500
# iter: 7/20 perturb: 140/500
# iter: 7/20 perturb: 150/500
# iter: 7/20 perturb: 160/500
# iter: 7/20 perturb: 170/500
# iter: 7/20 perturb: 180/500
# iter: 7/20 perturb: 190/500
# iter: 7/20 perturb: 200/500
# iter: 7/20 perturb: 210/500
# iter: 7/20 perturb: 220/500
# iter: 7/20 perturb: 230/500
# iter: 7/20 perturb: 240/500
# iter: 7/20 perturb: 250/500
# iter: 7/20 perturb: 260/500
# iter: 7/20 perturb: 270/500
# iter: 7/20 perturb: 280/500
# iter: 7/20 perturb: 290/500
# iter: 7/20 perturb: 300/500
# iter: 7/20 perturb: 310/500
# iter: 7/20 perturb: 320/500
# iter: 7/20 perturb: 330/500
# iter: 7/20 perturb: 340/500
# iter: 7/20 perturb: 350/500
# iter: 7/20 perturb: 360/500
# iter: 7/20 perturb: 370/500
# iter: 7/20 perturb: 380/500
# iter: 7/20 perturb: 390/500
# iter: 7/20 perturb: 400/500
# iter: 7/20 perturb: 410/500
# iter: 7/20 perturb: 420/500
# iter: 7/20 perturb: 430/500
# iter: 7/20 perturb: 440/500
# iter: 7/20 perturb: 450/500
# iter: 7/20 perturb: 460/500
# iter: 7/20 perturb: 470/500
# iter: 7/20 perturb: 480/500
# iter: 7/20 perturb: 490/500
# iter: 7/20 perturb: 500/500
# iter: 8/20 perturb: 10/500
# iter: 8/20 perturb: 20/500
# iter: 8/20 perturb: 30/500
# iter: 8/20 perturb: 40/500
# iter: 8/20 perturb: 50/500
# iter: 8/20 perturb: 60/500
# iter: 8/20 perturb: 70/500
# iter: 8/20 perturb: 80/500
# iter: 8/20 perturb: 90/500
# iter: 8/20 perturb: 100/500
# iter: 8/20 perturb: 110/500
# iter: 8/20 perturb: 120/500
# iter: 8/20 perturb: 130/500
# iter: 8/20 perturb: 140/500
# iter: 8/20 perturb: 150/500
# iter: 8/20 perturb: 160/500
# iter: 8/20 perturb: 170/500
# iter: 8/20 perturb: 180/500
# iter: 8/20 perturb: 190/500
# iter: 8/20 perturb: 200/500
# iter: 8/20 perturb: 210/500
# iter: 8/20 perturb: 220/500
# iter: 8/20 perturb: 230/500
# iter: 8/20 perturb: 240/500
# iter: 8/20 perturb: 250/500
# iter: 8/20 perturb: 260/500
# iter: 8/20 perturb: 270/500
# iter: 8/20 perturb: 280/500
# iter: 8/20 perturb: 290/500
# iter: 8/20 perturb: 300/500
# iter: 8/20 perturb: 310/500
# iter: 8/20 perturb: 320/500
# iter: 8/20 perturb: 330/500
# iter: 8/20 perturb: 340/500
# iter: 8/20 perturb: 350/500
# iter: 8/20 perturb: 360/500
# iter: 8/20 perturb: 370/500
# iter: 8/20 perturb: 380/500
# iter: 8/20 perturb: 390/500
# iter: 8/20 perturb: 400/500
# iter: 8/20 perturb: 410/500
# iter: 8/20 perturb: 420/500
# iter: 8/20 perturb: 430/500
# iter: 8/20 perturb: 440/500
# iter: 8/20 perturb: 450/500
# iter: 8/20 perturb: 460/500
# iter: 8/20 perturb: 470/500
# iter: 8/20 perturb: 480/500
# iter: 8/20 perturb: 490/500
# iter: 8/20 perturb: 500/500
# iter: 9/20 perturb: 10/500
# iter: 9/20 perturb: 20/500
# iter: 9/20 perturb: 30/500
# iter: 9/20 perturb: 40/500
# iter: 9/20 perturb: 50/500
# iter: 9/20 perturb: 60/500
# iter: 9/20 perturb: 70/500
# iter: 9/20 perturb: 80/500
# iter: 9/20 perturb: 90/500
# iter: 9/20 perturb: 100/500
# iter: 9/20 perturb: 110/500
# iter: 9/20 perturb: 120/500
# iter: 9/20 perturb: 130/500
# iter: 9/20 perturb: 140/500
# iter: 9/20 perturb: 150/500
# iter: 9/20 perturb: 160/500
# iter: 9/20 perturb: 170/500
# iter: 9/20 perturb: 180/500
# iter: 9/20 perturb: 190/500
# iter: 9/20 perturb: 200/500
# iter: 9/20 perturb: 210/500
# iter: 9/20 perturb: 220/500
# iter: 9/20 perturb: 230/500
# iter: 9/20 perturb: 240/500
# iter: 9/20 perturb: 250/500
# iter: 9/20 perturb: 260/500
# iter: 9/20 perturb: 270/500
# iter: 9/20 perturb: 280/500
# iter: 9/20 perturb: 290/500
# iter: 9/20 perturb: 300/500
# iter: 9/20 perturb: 310/500
# iter: 9/20 perturb: 320/500
# iter: 9/20 perturb: 330/500
# iter: 9/20 perturb: 340/500
# iter: 9/20 perturb: 350/500
# iter: 9/20 perturb: 360/500
# iter: 9/20 perturb: 370/500
# iter: 9/20 perturb: 380/500
# iter: 9/20 perturb: 390/500
# iter: 9/20 perturb: 400/500
# iter: 9/20 perturb: 410/500
# iter: 9/20 perturb: 420/500
# iter: 9/20 perturb: 430/500
# iter: 9/20 perturb: 440/500
# iter: 9/20 perturb: 450/500
# iter: 9/20 perturb: 460/500
# iter: 9/20 perturb: 470/500
# iter: 9/20 perturb: 480/500
# iter: 9/20 perturb: 490/500
# iter: 9/20 perturb: 500/500
# iter: 10/20 perturb: 10/500
# iter: 10/20 perturb: 20/500
# iter: 10/20 perturb: 30/500
# iter: 10/20 perturb: 40/500
# iter: 10/20 perturb: 50/500
# iter: 10/20 perturb: 60/500
# iter: 10/20 perturb: 70/500
# iter: 10/20 perturb: 80/500
# iter: 10/20 perturb: 90/500
# iter: 10/20 perturb: 100/500
# iter: 10/20 perturb: 110/500
# iter: 10/20 perturb: 120/500
# iter: 10/20 perturb: 130/500
# iter: 10/20 perturb: 140/500
# iter: 10/20 perturb: 150/500
# iter: 10/20 perturb: 160/500
# iter: 10/20 perturb: 170/500
# iter: 10/20 perturb: 180/500
# iter: 10/20 perturb: 190/500
# iter: 10/20 perturb: 200/500
# iter: 10/20 perturb: 210/500
# iter: 10/20 perturb: 220/500
# iter: 10/20 perturb: 230/500
# iter: 10/20 perturb: 240/500
# iter: 10/20 perturb: 250/500
# iter: 10/20 perturb: 260/500
# iter: 10/20 perturb: 270/500
# iter: 10/20 perturb: 280/500
# iter: 10/20 perturb: 290/500
# iter: 10/20 perturb: 300/500
# iter: 10/20 perturb: 310/500
# iter: 10/20 perturb: 320/500
# iter: 10/20 perturb: 330/500
# iter: 10/20 perturb: 340/500
# iter: 10/20 perturb: 350/500
# iter: 10/20 perturb: 360/500
# iter: 10/20 perturb: 370/500
# iter: 10/20 perturb: 380/500
# iter: 10/20 perturb: 390/500
# iter: 10/20 perturb: 400/500
# iter: 10/20 perturb: 410/500
# iter: 10/20 perturb: 420/500
# iter: 10/20 perturb: 430/500
# iter: 10/20 perturb: 440/500
# iter: 10/20 perturb: 450/500
# iter: 10/20 perturb: 460/500
# iter: 10/20 perturb: 470/500
# iter: 10/20 perturb: 480/500
# iter: 10/20 perturb: 490/500
# iter: 10/20 perturb: 500/500
# iter: 11/20 perturb: 10/500
# iter: 11/20 perturb: 20/500
# iter: 11/20 perturb: 30/500
# iter: 11/20 perturb: 40/500
# iter: 11/20 perturb: 50/500
# iter: 11/20 perturb: 60/500
# iter: 11/20 perturb: 70/500
# iter: 11/20 perturb: 80/500
# iter: 11/20 perturb: 90/500
# iter: 11/20 perturb: 100/500
# iter: 11/20 perturb: 110/500
# iter: 11/20 perturb: 120/500
# iter: 11/20 perturb: 130/500
# iter: 11/20 perturb: 140/500
# iter: 11/20 perturb: 150/500
# iter: 11/20 perturb: 160/500
# iter: 11/20 perturb: 170/500
# iter: 11/20 perturb: 180/500
# iter: 11/20 perturb: 190/500
# iter: 11/20 perturb: 200/500
# iter: 11/20 perturb: 210/500
# iter: 11/20 perturb: 220/500
# iter: 11/20 perturb: 230/500
# iter: 11/20 perturb: 240/500
# iter: 11/20 perturb: 250/500
# iter: 11/20 perturb: 260/500
# iter: 11/20 perturb: 270/500
# iter: 11/20 perturb: 280/500
# iter: 11/20 perturb: 290/500
# iter: 11/20 perturb: 300/500
# iter: 11/20 perturb: 310/500
# iter: 11/20 perturb: 320/500
# iter: 11/20 perturb: 330/500
# iter: 11/20 perturb: 340/500
# iter: 11/20 perturb: 350/500
# iter: 11/20 perturb: 360/500
# iter: 11/20 perturb: 370/500
# iter: 11/20 perturb: 380/500
# iter: 11/20 perturb: 390/500
# iter: 11/20 perturb: 400/500
# iter: 11/20 perturb: 410/500
# iter: 11/20 perturb: 420/500
# iter: 11/20 perturb: 430/500
# iter: 11/20 perturb: 440/500
# iter: 11/20 perturb: 450/500
# iter: 11/20 perturb: 460/500
# iter: 11/20 perturb: 470/500
# iter: 11/20 perturb: 480/500
# iter: 11/20 perturb: 490/500
# iter: 11/20 perturb: 500/500
# iter: 12/20 perturb: 10/500
# iter: 12/20 perturb: 20/500
# iter: 12/20 perturb: 30/500
# iter: 12/20 perturb: 40/500
# iter: 12/20 perturb: 50/500
# iter: 12/20 perturb: 60/500
# iter: 12/20 perturb: 70/500
# iter: 12/20 perturb: 80/500
# iter: 12/20 perturb: 90/500
# iter: 12/20 perturb: 100/500
# iter: 12/20 perturb: 110/500
# iter: 12/20 perturb: 120/500
# iter: 12/20 perturb: 130/500
# iter: 12/20 perturb: 140/500
# iter: 12/20 perturb: 150/500
# iter: 12/20 perturb: 160/500
# iter: 12/20 perturb: 170/500
# iter: 12/20 perturb: 180/500
# iter: 12/20 perturb: 190/500
# iter: 12/20 perturb: 200/500
# iter: 12/20 perturb: 210/500
# iter: 12/20 perturb: 220/500
# iter: 12/20 perturb: 230/500
# iter: 12/20 perturb: 240/500
# iter: 12/20 perturb: 250/500
# iter: 12/20 perturb: 260/500
# iter: 12/20 perturb: 270/500
# iter: 12/20 perturb: 280/500
# iter: 12/20 perturb: 290/500
# iter: 12/20 perturb: 300/500
# iter: 12/20 perturb: 310/500
# iter: 12/20 perturb: 320/500
# iter: 12/20 perturb: 330/500
# iter: 12/20 perturb: 340/500
# iter: 12/20 perturb: 350/500
# iter: 12/20 perturb: 360/500
# iter: 12/20 perturb: 370/500
# iter: 12/20 perturb: 380/500
# iter: 12/20 perturb: 390/500
# iter: 12/20 perturb: 400/500
# iter: 12/20 perturb: 410/500
# iter: 12/20 perturb: 420/500
# iter: 12/20 perturb: 430/500
# iter: 12/20 perturb: 440/500
# iter: 12/20 perturb: 450/500
# iter: 12/20 perturb: 460/500
# iter: 12/20 perturb: 470/500
# iter: 12/20 perturb: 480/500
# iter: 12/20 perturb: 490/500
# iter: 12/20 perturb: 500/500
# iter: 13/20 perturb: 10/500
# iter: 13/20 perturb: 20/500
# iter: 13/20 perturb: 30/500
# iter: 13/20 perturb: 40/500
# iter: 13/20 perturb: 50/500
# iter: 13/20 perturb: 60/500
# iter: 13/20 perturb: 70/500
# iter: 13/20 perturb: 80/500
# iter: 13/20 perturb: 90/500
# iter: 13/20 perturb: 100/500
# iter: 13/20 perturb: 110/500
# iter: 13/20 perturb: 120/500
# iter: 13/20 perturb: 130/500
# iter: 13/20 perturb: 140/500
# iter: 13/20 perturb: 150/500
# iter: 13/20 perturb: 160/500
# iter: 13/20 perturb: 170/500
# iter: 13/20 perturb: 180/500
# iter: 13/20 perturb: 190/500
# iter: 13/20 perturb: 200/500
# iter: 13/20 perturb: 210/500
# iter: 13/20 perturb: 220/500
# iter: 13/20 perturb: 230/500
# iter: 13/20 perturb: 240/500
# iter: 13/20 perturb: 250/500
# iter: 13/20 perturb: 260/500
# iter: 13/20 perturb: 270/500
# iter: 13/20 perturb: 280/500
# iter: 13/20 perturb: 290/500
# iter: 13/20 perturb: 300/500
# iter: 13/20 perturb: 310/500
# iter: 13/20 perturb: 320/500
# iter: 13/20 perturb: 330/500
# iter: 13/20 perturb: 340/500
# iter: 13/20 perturb: 350/500
# iter: 13/20 perturb: 360/500
# iter: 13/20 perturb: 370/500
# iter: 13/20 perturb: 380/500
# iter: 13/20 perturb: 390/500
# iter: 13/20 perturb: 400/500
# iter: 13/20 perturb: 410/500
# iter: 13/20 perturb: 420/500
# iter: 13/20 perturb: 430/500
# iter: 13/20 perturb: 440/500
# iter: 13/20 perturb: 450/500
# iter: 13/20 perturb: 460/500
# iter: 13/20 perturb: 470/500
# iter: 13/20 perturb: 480/500
# iter: 13/20 perturb: 490/500
# iter: 13/20 perturb: 500/500
# iter: 14/20 perturb: 10/500
# iter: 14/20 perturb: 20/500
# iter: 14/20 perturb: 30/500
# iter: 14/20 perturb: 40/500
# iter: 14/20 perturb: 50/500
# iter: 14/20 perturb: 60/500
# iter: 14/20 perturb: 70/500
# iter: 14/20 perturb: 80/500
# iter: 14/20 perturb: 90/500
# iter: 14/20 perturb: 100/500
# iter: 14/20 perturb: 110/500
# iter: 14/20 perturb: 120/500
# iter: 14/20 perturb: 130/500
# iter: 14/20 perturb: 140/500
# iter: 14/20 perturb: 150/500
# iter: 14/20 perturb: 160/500
# iter: 14/20 perturb: 170/500
# iter: 14/20 perturb: 180/500
# iter: 14/20 perturb: 190/500
# iter: 14/20 perturb: 200/500
# iter: 14/20 perturb: 210/500
# iter: 14/20 perturb: 220/500
# iter: 14/20 perturb: 230/500
# iter: 14/20 perturb: 240/500
# iter: 14/20 perturb: 250/500
# iter: 14/20 perturb: 260/500
# iter: 14/20 perturb: 270/500
# iter: 14/20 perturb: 280/500
# iter: 14/20 perturb: 290/500
# iter: 14/20 perturb: 300/500
# iter: 14/20 perturb: 310/500
# iter: 14/20 perturb: 320/500
# iter: 14/20 perturb: 330/500
# iter: 14/20 perturb: 340/500
# iter: 14/20 perturb: 350/500
# iter: 14/20 perturb: 360/500
# iter: 14/20 perturb: 370/500
# iter: 14/20 perturb: 380/500
# iter: 14/20 perturb: 390/500
# iter: 14/20 perturb: 400/500
# iter: 14/20 perturb: 410/500
# iter: 14/20 perturb: 420/500
# iter: 14/20 perturb: 430/500
# iter: 14/20 perturb: 440/500
# iter: 14/20 perturb: 450/500
# iter: 14/20 perturb: 460/500
# iter: 14/20 perturb: 470/500
# iter: 14/20 perturb: 480/500
# iter: 14/20 perturb: 490/500
# iter: 14/20 perturb: 500/500
# iter: 15/20 perturb: 10/500
# iter: 15/20 perturb: 20/500
# iter: 15/20 perturb: 30/500
# iter: 15/20 perturb: 40/500
# iter: 15/20 perturb: 50/500
# iter: 15/20 perturb: 60/500
# iter: 15/20 perturb: 70/500
# iter: 15/20 perturb: 80/500
# iter: 15/20 perturb: 90/500
# iter: 15/20 perturb: 100/500
# iter: 15/20 perturb: 110/500
# iter: 15/20 perturb: 120/500
# iter: 15/20 perturb: 130/500
# iter: 15/20 perturb: 140/500
# iter: 15/20 perturb: 150/500
# iter: 15/20 perturb: 160/500
# iter: 15/20 perturb: 170/500
# iter: 15/20 perturb: 180/500
# iter: 15/20 perturb: 190/500
# iter: 15/20 perturb: 200/500
# iter: 15/20 perturb: 210/500
# iter: 15/20 perturb: 220/500
# iter: 15/20 perturb: 230/500
# iter: 15/20 perturb: 240/500
# iter: 15/20 perturb: 250/500
# iter: 15/20 perturb: 260/500
# iter: 15/20 perturb: 270/500
# iter: 15/20 perturb: 280/500
# iter: 15/20 perturb: 290/500
# iter: 15/20 perturb: 300/500
# iter: 15/20 perturb: 310/500
# iter: 15/20 perturb: 320/500
# iter: 15/20 perturb: 330/500
# iter: 15/20 perturb: 340/500
# iter: 15/20 perturb: 350/500
# iter: 15/20 perturb: 360/500
# iter: 15/20 perturb: 370/500
# iter: 15/20 perturb: 380/500
# iter: 15/20 perturb: 390/500
# iter: 15/20 perturb: 400/500
# iter: 15/20 perturb: 410/500
# iter: 15/20 perturb: 420/500
# iter: 15/20 perturb: 430/500
# iter: 15/20 perturb: 440/500
# iter: 15/20 perturb: 450/500
# iter: 15/20 perturb: 460/500
# iter: 15/20 perturb: 470/500
# iter: 15/20 perturb: 480/500
# iter: 15/20 perturb: 490/500
# iter: 15/20 perturb: 500/500
# iter: 16/20 perturb: 10/500
# iter: 16/20 perturb: 20/500
# iter: 16/20 perturb: 30/500
# iter: 16/20 perturb: 40/500
# iter: 16/20 perturb: 50/500
# iter: 16/20 perturb: 60/500
# iter: 16/20 perturb: 70/500
# iter: 16/20 perturb: 80/500
# iter: 16/20 perturb: 90/500
# iter: 16/20 perturb: 100/500
# iter: 16/20 perturb: 110/500
# iter: 16/20 perturb: 120/500
# iter: 16/20 perturb: 130/500
# iter: 16/20 perturb: 140/500
# iter: 16/20 perturb: 150/500
# iter: 16/20 perturb: 160/500
# iter: 16/20 perturb: 170/500
# iter: 16/20 perturb: 180/500
# iter: 16/20 perturb: 190/500
# iter: 16/20 perturb: 200/500
# iter: 16/20 perturb: 210/500
# iter: 16/20 perturb: 220/500
# iter: 16/20 perturb: 230/500
# iter: 16/20 perturb: 240/500
# iter: 16/20 perturb: 250/500
# iter: 16/20 perturb: 260/500
# iter: 16/20 perturb: 270/500
# iter: 16/20 perturb: 280/500
# iter: 16/20 perturb: 290/500
# iter: 16/20 perturb: 300/500
# iter: 16/20 perturb: 310/500
# iter: 16/20 perturb: 320/500
# iter: 16/20 perturb: 330/500
# iter: 16/20 perturb: 340/500
# iter: 16/20 perturb: 350/500
# iter: 16/20 perturb: 360/500
# iter: 16/20 perturb: 370/500
# iter: 16/20 perturb: 380/500
# iter: 16/20 perturb: 390/500
# iter: 16/20 perturb: 400/500
# iter: 16/20 perturb: 410/500
# iter: 16/20 perturb: 420/500
# iter: 16/20 perturb: 430/500
# iter: 16/20 perturb: 440/500
# iter: 16/20 perturb: 450/500
# iter: 16/20 perturb: 460/500
# iter: 16/20 perturb: 470/500
# iter: 16/20 perturb: 480/500
# iter: 16/20 perturb: 490/500
# iter: 16/20 perturb: 500/500
# iter: 17/20 perturb: 10/500
# iter: 17/20 perturb: 20/500
# iter: 17/20 perturb: 30/500
# iter: 17/20 perturb: 40/500
# iter: 17/20 perturb: 50/500
# iter: 17/20 perturb: 60/500
# iter: 17/20 perturb: 70/500
# iter: 17/20 perturb: 80/500
# iter: 17/20 perturb: 90/500
# iter: 17/20 perturb: 100/500
# iter: 17/20 perturb: 110/500
# iter: 17/20 perturb: 120/500
# iter: 17/20 perturb: 130/500
# iter: 17/20 perturb: 140/500
# iter: 17/20 perturb: 150/500
# iter: 17/20 perturb: 160/500
# iter: 17/20 perturb: 170/500
# iter: 17/20 perturb: 180/500
# iter: 17/20 perturb: 190/500
# iter: 17/20 perturb: 200/500
# iter: 17/20 perturb: 210/500
# iter: 17/20 perturb: 220/500
# iter: 17/20 perturb: 230/500
# iter: 17/20 perturb: 240/500
# iter: 17/20 perturb: 250/500
# iter: 17/20 perturb: 260/500
# iter: 17/20 perturb: 270/500
# iter: 17/20 perturb: 280/500
# iter: 17/20 perturb: 290/500
# iter: 17/20 perturb: 300/500
# iter: 17/20 perturb: 310/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 20
#      18 mixed_linear.load_state_dict(state_dict)
#      19 mixed_linear.to(device)
# ---> 20 perturbed_preds = mixed_linear(feature_backbone, core_model_state_dict, data)
#      21 perturbed_loss = criterion(perturbed_preds, label)
#      22 forget_loss_differences[perturb_idx] += (perturbed_loss - actual_loss) * 2 * data.shape[0]
#
# File ~/miniconda3/envs/pytorch-stable/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch-stable/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Desktop/umityigitbsrn/mixed-privacy-forgetting/model.py:114, in MixedLinear.forward(self, feature_backbone, core_model_params, inp)
#     112 def forward(self, feature_backbone, core_model_params, inp):
#     113     with torch.no_grad():
# --> 114         inp = feature_backbone(inp)
#     116     dual_params = {}
#     117     with fwAD.dual_level():
#
# File ~/miniconda3/envs/pytorch-stable/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch-stable/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/envs/pytorch-stable/lib/python3.9/site-packages/torch/nn/modules/container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File ~/miniconda3/envs/pytorch-stable/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/pytorch-stable/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/envs/pytorch-stable/lib/python3.9/site-packages/torch/nn/modules/batchnorm.py:175, in _BatchNorm.forward(self, input)
#     168     bn_training = (self.running_mean is None) and (self.running_var is None)
#     170 r"""
#     171 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     172 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     173 used for normalization (i.e. in eval mode when buffers are not None).
#     174 """
# --> 175 return F.batch_norm(
#     176     input,
#     177     # If buffers are not to be tracked, ensure that they won't be updated
#     178     self.running_mean
#     179     if not self.training or self.track_running_stats
#     180     else None,
#     181     self.running_var if not self.training or self.track_running_stats else None,
#     182     self.weight,
#     183     self.bias,
#     184     bn_training,
#     185     exponential_average_factor,
#     186     self.eps,
#     187 )
#
# File ~/miniconda3/envs/pytorch-stable/lib/python3.9/site-packages/torch/nn/functional.py:2482, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2479 if training:
#    2480     _verify_batch_size(input.size())
# -> 2482 return torch.batch_norm(
#    2483     input, weight, bias, running_mean, running_var, training, momentum, eps, torch.backends.cudnn.enabled
#    2484 )
#
# KeyboardInterrupt:

# %%
# set optimization problem
